# %%
#intoduction to sets
L=[1,1,1,1,1,1,1,2,2,2,3,3,3,5]
s = set(L)
print(type(s))

for i in s:
  if i == 3:
    print("Amazing India")
  elif i == 5:  
    print("incredible India")
  else:
    print("LOL")

# %% [markdown]
# #make a class for making a shirt or tshirt
# class clohing()
#   gender
#
#   size
#
#   color
#
#   type
#    - shirt
#    - tshit
#
#   fabric
#       - cotton
#       - lennen
#
#   sleeves
#       - full sleeves
#       - half sleeves
#
#   buttons
#     if yes
#       - henley neck
#       - polo with button
#       - full-button
#     if no
#       - round neck
#       - v neck
#       - polo
#
#   pattern
#       - strips
#       - dots
#
#   designs
#       if yes
#           - embroidary
#           - rubber print
#           - vinyl print
#           - hand art
#           - digital print
#       if no
#           - plain

# %% [markdown]
# #make a class for home
#
# property_type
#
# buy_type
#
#     - rent
#     - buy
#
# area_in_sqft
#
# carpet_area
#
# price range
#
# floor
#
# furnished
#
#       if yes
#           - fully furnished
#           - half furnished
#       if no
#           - no furnished
#
# no_of_bedrooms
#
# no_of_bathrooms
#
# no_of_toilets
#
# floor_type
#
#       - marbel
#       - white tile
#
# kitchen
#
# suitable_for
#     - bachelors
#     -small_family
#     - large_family

# %%
str = "1,2,3,4"
a = str.split(",")
print(a)
print(type(a))

# %%
from statistics import mode 
from math import sqrt

numbers = input("Enter sequence of numbers separated by ',' : ")

list = numbers.split(",")

# Mean = x1+x2+x3....+xn / n
def calculate_mean():
  sum = 0
  for i in list:
    sum += int(i)
  mean = sum / len(list)
  return mean

# Median = Middle value of list after ascending order (if total number of elements in list is odd)
# Median = Middle two value of list after ascending order / 2 (if total number of elements in list is even)
def calculate_median():
  if len(list)%2 != 0:
    n = int(len(list)/2)
    median = list[n]
    return median
  else:
    m = int(len(list)/2) - 1
    n = int(len(list)/2)
    avg = int(list[m]) + int(list [n])
    median = avg / 2
    return median
    
#Mode = Maximum number of occurances by a particular number in a list
def calculate_mode(list): 
	return mode(list) 

mean_value = calculate_mean() 
print(f"Mean : {mean_value}")

median_value = calculate_median()
print(f"Median : {median_value}")

mode_value = calculate_mode(list)
print(f"Mode : {mode_value}")


#variance = sumission of square of difference between each element and mean / number of elements
def calculate_variance():
  sumission = 0
  for i in list:
    difference = (int(i) - mean_value)**2
    sumission = sumission + difference
  return sumission

variance = calculate_variance()
print(f"Variance : {variance}")

standard_deviation = sqrt(calculate_variance())
print(f"Standard Deviation : {standard_deviation}")

# %% [markdown]
# #Assignment 5:
# 1. Program to write law of thermodynamics - 3 Laws
# 2. Read about Word roots
# 3. Read 'word power made easy' : book
# 4. Types of brackets in programming : (),[],<>,{}
# 5. Publish book on penguin books :  Learn Python in 60 Days
# 6. Till Chapter 1 to 12 : Do all Try it yourself section code (Github)
# 7. Regster on Code Gladiators and prticipate in cometition.
# 8. Study about self() and __init()__ in python
# 9. Read about Roko's Basilisk and write a program similar to the theory
# 10. Import time modul to check execution time
# 11. Read books
#         - Learn python the hard way : till page 250
#         - Python Crash Course book: till page 180
# 12. Write a program to calculate following:
#         - Mean
#         - Mode
#         - Median
#         - Variance
#         - Standard Deviation
# 13. Use SCRUM methodlogy to solve problem
# 	      - profit and loss
# 	      - check amount input for stock
# 14. Read about whitepapers and remind Vedant about it.
